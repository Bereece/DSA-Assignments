# %% [markdown]
# <a href="https://colab.research.google.com/github/Bereece/DSA-Assignments/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data structures and Algorithims
# ># Assignment 1

# %% [markdown]
# # New Section

# %% [markdown]
# ***Question 1***
# <br> Write a python program that takes two numbers as the input such as X and Y and print the result
# of X^Y(X to the power of Y).

# %%
X= int(input('Enter val1: '))
Y= int(input('Enter val2: '))
print(X**Y)
# Out:
# Enter val1: 2
# Enter val2: 5
# 32

# %% [markdown]
# **Question 2**
# <br>Write a Python program to print the numbers in the list which are divisible by 3.

# %%
list= [23,10,6,19,30,8,15,99,67,89,9,55]
for i in list:
   if (i%3==0):
    print(i)
# Out:
# 6
# 30
# 15
# 99
# 9
